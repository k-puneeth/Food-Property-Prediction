# %% [markdown]
# # Clone Dataset

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Food\ Property\ Prediction
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %% [markdown]
# # Setup Project

# %%
import os

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %%
path = "/content/drive/MyDrive/Food Property Prediction/src"

# %%
os.mkdir(path)

# %%
# %cd src

print("hello world!")
# Out:
# [Errno 2] No such file or directory: 'src'
# /content/drive/MyDrive/Food Property Prediction/src
# hello world!

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Food Property Prediction/src

# %%
# !echo "ECUSTFD-resized-" > .gitignore

# %%
# !touch __init__.py

# %%
# !touch dataloader.py

# %%
import pandas as pd

# %%
# %cd /content/drive/MyDrive/Food\ Property\ Prediction
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %%
xls = pd.ExcelFile('ECUSTFD-resized-/density.xls')

# %%
xls.sheet_names
# Out:
# ['apple',
#  'banana',
#  'bread',
#  'bun',
#  'doughnut',
#  'egg',
#  'fired_dough_twist',
#  'grape',
#  'lemon',
#  'litchi',
#  'mango',
#  'mix',
#  'mooncake',
#  'orange',
#  'pear',
#  'peach',
#  'plum',
#  'qiwi',
#  'sachima',
#  'tomato']

# %%
from src.dataloader import FoodPredictionDataset

# %%
face_dataset = FoodPredictionDataset(root_dir="ECUSTFD-resized-", mode="train")

# %%
for i in range(len(face_dataset)):
    sample = face_dataset[i]

    print(i, sample['image'].shape, sample['landmarks'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f25f0ddb32c3> in <cell line: 1>()
#       1 for i in range(len(face_dataset)):
# ----> 2     sample = face_dataset[i]
#       3
#       4     print(i, sample['image'].shape, sample['landmarks'])
#
# /content/drive/MyDrive/Food Property Prediction/src/dataloader.py in __getitem__(self, idx)
#      50
#      51         img_name = self.Images[idx]
# ---> 52         image = io.imread(os.path.join(self.root_dir, "JPEGImages", f"{img_name}.JPG"))
#      53
#      54         tree = ET.parse(os.path.join(self.root_dir, "Annotations", f"{img_name}.xml"))
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
# ...

# %%
/content/drive/MyDrive/Food Property Prediction/ECUSTFD-resized-/JPEGImages/apple001S(1).JPG
/content/drive/MyDrive/Food Property Prediction/ECUSTFD-resized-/JPEGImages/apple001S(1).JPG
# Out:
#   File "<ipython-input-9-d8460c5b43df>", line 1
#     content/drive/MyDrive/Food(Property, Prediction/ECUSTFD-resized-/JPEGImages/apple001S(1).JPG)
#                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Git Setup

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Food Property Prediction/.git/

# %%
# !echo ".ipynb_checkpoints" >> .gitignore

# %%
# !echo "ECUSTFD-resized-" >> .gitignore

# %%
# !echo "output" >> .gitignore

# %%
# !git add .

# %%
# !ls
# Out:
#  DepthEstimation.ipynb	 Main.ipynb		 PointCloud.ipynb
# 'ECUSTFD Github.ipynb'	 ObjectDetection.ipynb	 SemanticSegmentation.ipynb
#  ECUSTFD-resized-	 output			 src

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) e81d38e] first commit
#  19 files changed, 272 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 DepthEstimation.ipynb
#  create mode 100644 ECUSTFD Github.ipynb
#  create mode 100644 Main.ipynb
#  create mode 100644 ObjectDetection.ipynb
#  create mode 100644 PointCloud.ipynb
#  create mode 100644 SemanticSegmentation.ipynb
#  create mode 100644 src/.gitignore
#  create mode 100644 src/__init__.py
#  create mode 100644 src/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 src/__pycache__/dataloader.cpython-310.pyc
#  create mode 100644 src/__pycache__/dataset.cpython-310.pyc
#  create mode 100644 src/__pycache__/depth_estimation.cpython-310.pyc
#  create mode 100644 src/__pycache__/semantic_segmentation.cpython-310.pyc
#  create mode 100644 src/dataset.py
#  create mode 100644 src/depth_estimation.py
#  create mode 100644 src/object_detection.py
#  create mode 100644 src/point_cloud.py
# ...

# %%
# !git config --global user.email "puneeth.sarma@iiitb.org"
# !git config --global user.name "k-puneeth"

# %%
# !git remote set-url origin https://k-puneeth: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@github.com/k-puneeth/Food-Property-Prediction.git

# %%
# !git remote -v
# Out:
# origin	https://k-puneeth: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@github.com/k-puneeth/Food-Property-Prediction.git (fetch)
# origin	https://k-puneeth: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@github.com/k-puneeth/Food-Property-Prediction.git (push)

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 1.30 KiB | 34.00 KiB/s, done.
# From https://github.com/k-puneeth/Food-Property-Prediction
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# ...

# %%
# !git pull --ff-only
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> master

# %%
# !pbcopy < ~/.ssh/id_ed25519.pub
# Out:
# /bin/bash: line 1: /root/.ssh/id_ed25519.pub: No such file or directory

# %%
# !rm -rf .git

# %%
# !cd ..

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Food Property Prediction

# %%
# %cd ..
# Out:
# /content/drive/MyDrive

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://k-puneeth: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@github.com/k-puneeth/Food-Property-Prediction.git
# Out:
# Cloning into 'Food-Property-Prediction'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.
